# %%
print("Hello Friends")
# Out:
# Hello Friends

# %%
# %sql
Create table emp(
  emp_id INT,
  name STRING,
  salary INT,
  department STRING,
  hire_date DATE
  );

# %%
# %sql

INSERT INTO emp VALUES
(1, 'Shalini', 50000, 'IT', '2018-01-01'),
(2, 'Nick', 60000, 'HR', '2019-01-01'),
(3, 'Matrika', 70000, 'IT', '2020-01-01'),
(4, 'Ravi', 80000, 'Finance', '2021-01-01'),
(5, 'Priya', 90000, 'IT', '2022-01-01');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
SELECT * 
FROM emp
ORDER BY salary DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Count Differences
#
# ### Explain difference between `COUNT(*)`, `COUNT(1)` and `COUNT(column)`
#
# `COUNT(*)` - counts all rows, including rows with NULL values
# `COUNT(1)` - also counts all rows; effectively same as `COUNT(*)`
# `COUNT(column)` - counts only non-NULL values in that column

# %%
# %sql
select department, sum(salary) AS total_salary
from emp
group by department
order by total_salary desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total_salary</th></tr></thead><tbody><tr><td>IT</td><td>840000</td></tr><tr><td>Finance</td><td>320000</td></tr><tr><td>HR</td><td>240000</td></tr></tbody></table></div>

# %%
# %sql
SELECT department, count(*) AS emp_count
FROM emp
GROUP BY department;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>emp_count</th></tr></thead><tbody><tr><td>IT</td><td>12</td></tr><tr><td>HR</td><td>4</td></tr><tr><td>Finance</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
select max(hire_date)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7039302046075042>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select max(hire_date)\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:205, in SqlMagic.sql(self, line, cell)
#     198 except BaseException as e:
# ...

# %%
# %sql
select *
from emp
where hire_date = (select max(hire_date) from emp);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th><th>department</th><th>hire_date</th></tr></thead><tbody><tr><td>5</td><td>Priya</td><td>90000</td><td>IT</td><td>2022-01-01</td></tr><tr><td>5</td><td>Priya</td><td>90000</td><td>IT</td><td>2022-01-01</td></tr><tr><td>5</td><td>Priya</td><td>90000</td><td>IT</td><td>2022-01-01</td></tr><tr><td>5</td><td>Priya</td><td>90000</td><td>IT</td><td>2022-01-01</td></tr></tbody></table></div>

# %%
# %sql
SELECT department, MAX(salary) AS highest_salary
FROM emp
GROUP BY department
ORDER BY highest_salary DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>highest_salary</th></tr></thead><tbody><tr><td>IT</td><td>90000</td></tr><tr><td>Finance</td><td>80000</td></tr><tr><td>HR</td><td>60000</td></tr></tbody></table></div>

# %%
# %sql
SELECT department, AVG(salary) AS avg_salary
FROM emp
GROUP BY department
ORDER BY avg_salary DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg_salary</th></tr></thead><tbody><tr><td>Finance</td><td>80000.0</td></tr><tr><td>IT</td><td>70000.0</td></tr><tr><td>HR</td><td>60000.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS employee_count
FROM emp
WHERE hire_date > '2022-01-01';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_count</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>
