# %% [markdown]
# index starts from 0 , length starts from 1

# %% [markdown]
# Adding and removing element

# %%
Tuple

# %%
my_tuple=(10,20,30,40,50)
my_tuple
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# #Tuple with immutable-once created we cannot change its value
# #it has ordered sequence same as list it also has an index
# #but memories is fixed becuase we cannot modify it

# %%
my_tuple[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 my_tuple[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#mixed data types
data = (10,"Ishwor",2.7,False)
print(data)
# Out:
# (10, 'Ishwor', 2.7, False)

# %%
#tuple slicing
my_tuple[1:4]
# Out:
# (20, 30, 40)

# %%
my_tuple[-3:]
# Out:
# (30, 40, 50)

# %% [markdown]
# #negative-when we want last elements without knowing list/tuplesize
# #Zip function-it combines mutliple collection into pairs,it groups elemts based on index position

# %%
coders=["Nisha","Ishwor","Matrika","Bipina","Suraj"]
marks=[50,60,80,90,96]

list(zip(coders,marks))
# Out:
# [('Nisha', 50), ('Ishwor', 60), ('Matrika', 80), ('Bipina', 90), ('Suraj', 96)]

# %%
#index wise mapping
#index 0 -nisha +50
#zip returns zip object not a list

# %%
zip(coders,marks)

# %%
alphabet=["A","B","C"]
num=[80,90]
list(zip(alphabet,num))
# Out:
# [('A', 80), ('B', 90)]

# %% [markdown]
# #Zip starts at the shortest list
